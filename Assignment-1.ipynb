# %% [markdown]
# # DMV Assignment-1

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Imported libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Dataset

# %%
df1 = pd.read_excel("sales_data_sample.xlsx")
df1.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
df2 = pd.read_json("csvjson.json")
df2.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# ...

# %%
df = pd.read_csv("sales_data_sample.csv")
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
all_data = pd.concat([df,df1,df2], ignore_index=True)
all_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
all_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
all_data.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 8464        10350               20     100.00               15  2244.40
# 8465        10373               29     100.00                1  3978.51
# 8466        10386               43     100.00                4  5417.57
# 8467        10397               34      62.24                1  2116.16
# 8468        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 8464  12/2/2004 0:00   Shipped       4        12     2004  ...
# 8465  1/31/2005 0:00   Shipped       1         1     2005  ...
# 8466   3/1/2005 0:00  Resolved       1         3     2005  ...
# 8467  3/28/2005 0:00   Shipped       1         3     2005  ...
# 8468   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %% [markdown]
# # Data Preprocessing

# %%
all_data.shape
# Out:
# (8469, 25)

# %%
all_data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
all_data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       8469 non-null   int64
#  1   QUANTITYORDERED   8469 non-null   int64
#  2   PRICEEACH         8469 non-null   float64
#  3   ORDERLINENUMBER   8469 non-null   int64
#  4   SALES             8469 non-null   float64
#  5   ORDERDATE         8469 non-null   object
#  6   STATUS            8469 non-null   object
#  7   QTR_ID            8469 non-null   int64
#  8   MONTH_ID          8469 non-null   int64
#  9   YEAR_ID           8469 non-null   int64
#  10  PRODUCTLINE       8469 non-null   object
#  11  MSRP              8469 non-null   int64
#  12  PRODUCTCODE       8469 non-null   object
#  13  CUSTOMERNAME      8469 non-null   object
#  14  PHONE             8469 non-null   object
#  15  ADDRESSLINE1      8469 non-null   object
# ...

# %%
all_data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   8469.000000      8469.000000  8469.000000      8469.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.074602         9.740292    20.171894         4.225342
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.800000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10334.000000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID      YEAR_ID         MSRP
# count   8469.000000  8469.000000  8469.000000  8469.000000  8469.000000
# mean    3553.889072     2.717676     7.092455  2003.815090   100.715551
# std     1841.647584     1.203736     3.656201     0.699588    40.183166
# min      482.130000     1.000000     1.000000  2003.000000    33.000000
# ...

# %%
all_data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        5041
# CITY                   0
# STATE               2972
# POSTALCODE           152
# COUNTRY                0
# TERRITORY           2147
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
all_data['ADDRESSLINE2'].fillna(all_data['ADDRESSLINE2'].mode()[0], inplace=True)
all_data['STATE'].fillna(all_data['STATE'].mode()[0], inplace=True)
all_data['POSTALCODE'].fillna(all_data['POSTALCODE'].mode()[0], inplace=True)
all_data['TERRITORY'].fillna(all_data['TERRITORY'].mode()[0], inplace=True)

# %%
all_data.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# ADDRESSLINE2        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %% [markdown]
# # Removing Duplicates

# %%
all_data.duplicated().sum()
# Out:
# 376

# %%
sales_data = all_data.drop_duplicates()
sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue                          NYC    NY
# ...

# %%
sales_data.shape
# Out:
# (8093, 25)

# %% [markdown]
# # Data Transformation

# %%
sales_data['SALES'] = sales_data['QUANTITYORDERED'] * sales_data['PRICEEACH']

# %%
total_sales = sales_data['SALES'].sum()
avg_order_value = sales_data['SALES'].mean()
category_distribution = sales_data['PRODUCTLINE'].value_counts()

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # 1. Bar plot

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=category_distribution.index, y=category_distribution.values)
plt.xticks(rotation=45)
plt.xlabel('Product Line')
plt.ylabel('Number of Sales')
plt.title('Product Line Distribution')
plt.show()

# %% [markdown]
# # 2.Box Plot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='PRODUCTLINE', y='SALES', data=all_data)
plt.xticks(rotation=45)
plt.xlabel('Product Line')
plt.ylabel('Sales')
plt.title('Sales Distribution by Product Line')
plt.show()

# %% [markdown]
# # 3.Scatter Plot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sales_data, x='QUANTITYORDERED', y='SALES')
plt.xlabel('Quantity Ordered')
plt.ylabel('Sales')
plt.title('Scatter Plot: Quantity Ordered vs. Sales')
plt.show()

# %% [markdown]
# # 4.Pie chart

# %%
plt.figure(figsize=(8, 8))
plt.pie(category_distribution, labels=category_distribution.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of Sales by Product Line')
plt.show()

# %% [markdown]
# # 5.Histogram

# %%
plt.figure(figsize=(10, 6))
plt.hist(category_distribution, bins=10, edgecolor='black')
plt.xlabel('Total Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Total Sales by Product Line')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # 6.Pair Plot

# %%
numeric_columns = ['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'MSRP']
sns.set(style="ticks")
sns.pairplot(sales_data[numeric_columns])
plt.suptitle('Pair Plot of Numeric Variables', y=1.02)
plt.show()

# %% [markdown]
# # Insights

# %%
print("Total Sales:", total_sales)
print("Average Order Value:", avg_order_value)
print("Product Line Distribution:\n", category_distribution)
# Out:
# Total Sales: 23776025.240000002
# Average Order Value: 2937.850641294947
# Product Line Distribution:
#  Classic Cars        2773
# Vintage Cars        1743
# Motorcycles          954
# Trucks and Buses     881
# Planes               867
# Ships                655
# Trains               220
# Name: PRODUCTLINE, dtype: int64
